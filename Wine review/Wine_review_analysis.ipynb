# %% [markdown]
# # Wine review
# Exploratory data analysis of wine review given by diffirent customers and tasters across diffirent countries.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud,STOPWORDS
import missingno as msno
import squarify

# %matplotlib inline
plt.style.use('fivethirtyeight')
plt.rcParams.update({'font.size':12})

# %% [markdown]
# ## Read data set

# %%
path = 'dataset/'
#path = '../input/'
wine_150k = pd.read_csv(path + 'winemag-data_first150k.csv',index_col=0)
wine_130k = pd.read_csv(path + 'winemag-data-130k-v2.csv',index_col=0)
wine = pd.concat([wine_150k,wine_130k],axis=0)
#wine = wine_150k
print("Number of rows and columns:",wine.shape)
# Out:
# /home/sudhir/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """
# Number of rows and columns: (280901, 13)

# %%
wine.head()
# Out:
#   country                                        description  \
# 0      US  This tremendous 100% varietal wine hails from ...
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      US  Mac Watson honors the memory of a wine once ma...
# 3      US  This spent 20 months in 30% new French oak, an...
# 4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2 taster_name taster_twitter_handle  \
# 0        Napa Valley               Napa         NaN                   NaN
# 1               Toro                NaN         NaN                   NaN
# 2     Knights Valley             Sonoma         NaN                   NaN
# 3  Willamette Valley  Willamette Valley         NaN                   NaN
# 4             Bandol                NaN         NaN                   NaN
#
#   title             variety                   winery
# 0   NaN  Cabernet Sauvignon                    Heitz
# 1   NaN       Tinta de Toro  Bodega Carmen Rodríguez
# 2   NaN     Sauvignon Blanc                 Macauley
# 3   NaN          Pinot Noir                    Ponzi
# 4   NaN  Provence red blend     Domaine de la Bégude

# %% [markdown]
# ## Data analysis

# %%
wine.describe(include='all',).T
# Out:
#                         count  unique  \
# country                280833      50
# description            280901  169430
# designation            197701   47239
# points                 280901     NaN
# price                  258210     NaN
# province               280833     490
# region_1               234594    1332
# region_2               111464      18
# taster_name            103727      19
# taster_twitter_handle   98758      15
# title                  129971  118840
# variety                280900     756
# winery                 280901   19186
#
#                                                                      top  \
# country                                                               US
# description            A little bit funky and unsettled when you pop ...
# designation                                                      Reserve
# points                                                               NaN
# price                                                                NaN
# province                                                      California
# region_1                                                     Napa Valley
# region_2                                                   Central Coast
# taster_name                                                   Roger Voss
# taster_twitter_handle                                         @vossroger
# title                  Gloria Ferrer NV Sonoma Brut Sparkling (Sonoma...
# variety                                                       Pinot Noir
# winery                                                   Williams Selyem
#
#                          freq     mean      std  min  25%  50%  75%   max
# country                116901      NaN      NaN  NaN  NaN  NaN  NaN   NaN
# description                 7      NaN      NaN  NaN  NaN  NaN  NaN   NaN
# designation              4761      NaN      NaN  NaN  NaN  NaN  NaN   NaN
# points                    NaN  88.1469  3.15153   80   86   88   90   100
# price                     NaN  34.1772  38.6117    4   16   25   40  3300
# province                80755      NaN      NaN  NaN  NaN  NaN  NaN   NaN
# region_1                10689      NaN      NaN  NaN  NaN  NaN  NaN   NaN
# region_2                24122      NaN      NaN  NaN  NaN  NaN  NaN   NaN
# taster_name             25514      NaN      NaN  NaN  NaN  NaN  NaN   NaN
# taster_twitter_handle   25514      NaN      NaN  NaN  NaN  NaN  NaN   NaN
# title                      11      NaN      NaN  NaN  NaN  NaN  NaN   NaN
# variety                 27563      NaN      NaN  NaN  NaN  NaN  NaN   NaN
# winery                    585      NaN      NaN  NaN  NaN  NaN  NaN   NaN

# %% [markdown]
# ## Missing values

# %%
msno.bar(wine,color= sns.color_palette('viridis'))

# %% [markdown]
# ## Distribution of Wine Reviews by Top 20 Countries

# %%
print('Number of country list in data:',wine['country'].nunique())
plt.figure(figsize=(14,10))
cnt = wine['country'].value_counts().to_frame()[0:20]
#plt.xscale('log')
sns.barplot(x= cnt['country'], y =cnt.index, data=cnt, palette='ocean',orient='h')
plt.title('Distribution of Wine Reviews by Top 20 Countrie');
# Out:
# Number of country list in data: 50

# %% [markdown]
# * Us contribute more in the review
# * The wine review for 50 countries in the dataset
# ***
# ## Distribution of wine price

# %%
f, ax = plt.subplots(1,2,figsize=(14,6))
ax1,ax2 = ax.flatten()
sns.distplot(wine['price'].fillna(wine['price'].mean()),color='r',ax=ax1)
ax1.set_title('Distrbution of price')
sns.boxplot(x = wine['price'], ax=ax2)
ax2.set_ylabel('')
ax2.set_title('Boxplot of price')
# Out:
# Text(0.5,1,'Boxplot of price')

# %% [markdown]
# * The price of wine is starts from 4 to more than 3000.
# * The price mean and median price is less than 100,
# * Thier is many outliers in the data

# %% [markdown]
# ## Country wise average wine price

# %%
cnt = wine.groupby(['country',]).mean()['price'].sort_values(ascending=False).to_frame()

plt.figure(figsize=(16,8))
sns.pointplot(x = cnt['price'] ,y = cnt.index ,color='r',orient='h',markers='o')
plt.title('Country wise average wine price')
plt.xlabel('Price')
plt.ylabel('Country');

# %%
cnt = wine.groupby(['country',])['price'].mean().sort_values(ascending=False).to_frame()
plt.figure(figsize=(12,8))
squarify.plot(cnt['price'].fillna(0.1),color=sns.color_palette('rainbow'),label=cnt.index)

# %% [markdown]
# * The average price of wine in 'Switzerland' is highest.
# * The country named 'Us-France' is present in data set, may wine manufacture in france is sold in US.
# ***
# ## Country wise Expensive and Least price wine

# %%
fig,ax = plt.subplots(1,2,figsize=(16,8))
ax1,ax2 = ax.flatten()

cnt = wine.groupby(['country'])['price'].max().sort_values(ascending=False).to_frame()[:15]
sns.barplot(x = cnt['price'], y = cnt.index, palette= 'inferno',ax=ax1)
ax1.set_title('Most expensive wine in country')
ax1.set_ylabel('Variety')
ax1.set_xlabel('')
cnt = wine.groupby(['country'])['price'].min().sort_values(ascending=True).to_frame()[:15]
sns.barplot(x = cnt['price'], y = cnt.index, palette = 'rainbow_r',ax=ax2)
ax2.set_title('Least price wine by country')
ax2.set_ylabel('')
ax2.set_xlabel('')
plt.subplots_adjust(wspace=0.3);

# %% [markdown]
# * The France is selling expensive wine followed by US Austria.
# * The least price wine availabe at 4 bucks at Portugal, Argentian,Spain,Romania and also US.
# * The most of European countries are selling wide range of wine.
# ***

# %%
plt.figure(figsize=(16,6))
sns.boxplot(x = wine['country'], y = wine['price'])
plt.yscale("log")
plt.title('Country wise boxplot of price (log scale)')
plt.xticks(rotation=90);

# %% [markdown]
# ## Average rating of wine by country wise
# * Points:The number of points WineEnthusiast rated the wine on a scale of 1-100 (though they say they only post reviews for wines that score >=80)

# %%
cnt = wine.groupby(['country',]).mean()['points'].sort_values(ascending=False).to_frame()

plt.figure(figsize=(16,8))
sns.pointplot(x = cnt['points'] ,y = cnt.index ,color='r',orient='h')
plt.title('Country wise average wine ratting')
plt.xlabel('Points');

# %% [markdown]
# * The average rating of wine for England is top in the table.
# * The coutries like Austria,Germany, India, France are top quality wine producing country.
# * South korea, Montenegro produces least quality wine.
# ***
# ## Country wise Highest and Least rated wine

# %%
fig,ax = plt.subplots(1,2,figsize=(16,8))
ax1,ax2 = ax.flatten()

cnt = wine.groupby(['country'])['points'].max().sort_values(ascending=False).to_frame()[:15]
sns.barplot(x = cnt['points'], y = cnt.index, palette= 'hot',ax=ax1)
ax1.set_title('Most rated wine in country')
ax1.set_ylabel('Variety')
ax1.set_xlabel('')
cnt = wine.groupby(['country'])['points'].min().sort_values(ascending=True).to_frame()[:15]
sns.barplot(x = cnt['points'], y = cnt.index, palette = 'ocean',ax=ax2)
ax2.set_title('Least rated wine by country')
ax2.set_ylabel('')
ax2.set_xlabel('')
plt.subplots_adjust(wspace=0.3);

# %% [markdown]
# * The rating of wine is varies from 0 to 100, but least rating is 80.
# * The wine produced in France, Australia, Portugal, Italy, US receives top rating.
# * The wine produced in Urugay, South Africa, Portugal reveices least rating.

# %%
plt.figure(figsize=(16,6))
sns.boxplot(x = wine['country'], y = wine['points'])
#sns.pointplot(x = wine['country'], y = wine['points'])
plt.title('Country wise boxplot of points')
plt.xticks(rotation=90);

# %% [markdown]
# ## Relation between Price and Points

# %%
sns.jointplot( x = wine['points'],y = wine['price'],color='g');

# %% [markdown]
# ## Top most wine by variety
# * Variety: the type of grapes used to make the wine (ie Pinot Noir)

# %%
print('Number of varity of wines',wine['variety'].nunique())
fig,ax = plt.subplots(1,2,figsize=(16,8))
ax1,ax2 = ax.flatten()

cnt = wine.groupby(['variety'])['price'].max().sort_values(ascending=False).to_frame()[:15]
sns.barplot(x = cnt['price'], y = cnt.index, palette= 'cool',ax=ax1)
ax1.set_title('The grapes used for most expensive wine')
ax1.set_ylabel('Variety')
ax1.set_xlabel('')
cnt = wine.groupby(['variety'])['points'].max().sort_values(ascending=False).to_frame()[:15]
sns.barplot(x = cnt['points'], y = cnt.index, palette = 'Wistia',ax=ax2)
ax2.set_title('The grapes used for most rated wine')
ax2.set_ylabel('')
ax2.set_xlabel('')
plt.subplots_adjust(wspace=0.3);
# Out:
# Number of varity of wines 756

# %%
fig,ax = plt.subplots(1,2,figsize=(16,8))
ax1,ax2 = ax.flatten()

cnt = wine.groupby(['variety'])['price'].min().sort_values(ascending=True).to_frame()[:15]
sns.barplot(x = cnt['price'], y = cnt.index,palette = 'ocean_r',ax=ax1)
ax1.set_title('The grapes used for least price wine')
ax1.set_xlabel('')
ax1.set_ylabel('Variety')

cnt = wine.groupby(['variety'])['points'].min().sort_values(ascending=True).to_frame()[:15]
sns.barplot(x = cnt['points'], y = cnt.index,palette= 'rainbow', ax=ax2)
ax2.set_title('The grapes used for least rated wine')
ax2.set_xlabel('')
ax2.set_ylabel('')
plt.subplots_adjust(wspace=0.4);

# %%
cnt = wine.groupby(['country','points'])['price'].agg(['count','min','max','mean']).sort_values(by='mean',ascending=False)[:10]
cnt.reset_index(inplace=True)
cnt.style.background_gradient(cmap='PuBu',high=0.5)
# Out:
# <style  type="text/css" >
#     #T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow0_col1 {
#             background-color:  #2685bb;
#         }    #T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow0_col2 {
#             background-color:  #e1dfed;
#         }    #T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow0_col3 {
#             background-color:  #f4edf6;
#         }    #T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow0_col4 {
#             background-color:  #a4bcda;
#         }    #T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow0_col5 {
#             background-color:  #2685bb;
#         }    #T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow1_col1 {
#             background-color:  #d7d6e9;
#         }    #T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow1_col2 {
#             background-color:  #fff7fb;
#         }    #T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow1_col3 {
#             background-color:  #2685bb;
#         }    #T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow1_col4 {
#             background-color:  #ede7f2;
#         }    #T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow1_col5 {
#             background-color:  #60a1ca;
#         }    #T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow2_col1 {
#             background-color:  #8bb2d4;
#         }    #T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow2_col2 {
#             background-color:  #e8e4f0;
#         }    #T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow2_col3 {
#             background-color:  #f2ecf5;
#         }    #T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow2_col4 {
#             background-color:  #2685bb;
#         }    #T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow2_col5 {
#             background-color:  #a9bfdc;
#         }    #T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow3_col1 {
#             background-color:  #8bb2d4;
#         }    #T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow3_col2 {
#             background-color:  #fdf5fa;
#         }    #T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow3_col3 {
#             background-color:  #d8d7e9;
#         }    #T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow3_col4 {
#             background-color:  #e7e3f0;
#         }    #T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow3_col5 {
#             background-color:  #c1cae2;
#         }    #T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow4_col1 {
#             background-color:  #2685bb;
#         }    #T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow4_col2 {
#             background-color:  #fdf5fa;
#         }    #T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow4_col3 {
#             background-color:  #acc0dd;
#         }    #T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow4_col4 {
#             background-color:  #f3edf5;
#         }    #T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow4_col5 {
#             background-color:  #cccfe5;
#         }    #T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow5_col1 {
#             background-color:  #d7d6e9;
#         }    #T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow5_col2 {
#             background-color:  #2685bb;
#         }    #T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow5_col3 {
#             background-color:  #fff7fb;
#         }    #T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow5_col4 {
#             background-color:  #67a4cc;
#         }    #T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow5_col5 {
#             background-color:  #e9e5f1;
#         }    #T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow6_col1 {
#             background-color:  #d7d6e9;
#         }    #T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow6_col2 {
#             background-color:  #faf3f9;
#         }    #T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow6_col3 {
#             background-color:  #afc1dd;
#         }    #T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow6_col4 {
#             background-color:  #fef6fa;
#         }    #T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow6_col5 {
#             background-color:  #e9e5f1;
#         }    #T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow7_col1 {
#             background-color:  #fff7fb;
#         }    #T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow7_col2 {
#             background-color:  #d3d4e7;
#         }    #T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow7_col3 {
#             background-color:  #e3e0ee;
#         }    #T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow7_col4 {
#             background-color:  #ede7f2;
#         }    #T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow7_col5 {
#             background-color:  #f4eef6;
#         }    #T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow8_col1 {
#             background-color:  #8bb2d4;
#         }    #T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow8_col2 {
#             background-color:  #faf3f9;
#         }    #T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow8_col3 {
#             background-color:  #dfddec;
#         }    #T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow8_col4 {
#             background-color:  #fff7fb;
#         }    #T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow8_col5 {
#             background-color:  #f8f1f8;
#         }    #T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow9_col1 {
#             background-color:  #2685bb;
#         }    #T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow9_col2 {
#             background-color:  #e5e1ef;
#         }    #T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow9_col3 {
#             background-color:  #ede8f3;
#         }    #T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow9_col4 {
#             background-color:  #f8f1f8;
#         }    #T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow9_col5 {
#             background-color:  #fff7fb;
#         }</style>
# <table id="T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3d" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >country</th>
#         <th class="col_heading level0 col1" >points</th>
#         <th class="col_heading level0 col2" >count</th>
#         <th class="col_heading level0 col3" >min</th>
#         <th class="col_heading level0 col4" >max</th>
#         <th class="col_heading level0 col5" >mean</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3dlevel0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow0_col0" class="data row0 col0" >France</td>
#         <td id="T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow0_col1" class="data row0 col1" >100</td>
#         <td id="T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow0_col2" class="data row0 col2" >12</td>
#         <td id="T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow0_col3" class="data row0 col3" >150</td>
#         <td id="T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow0_col4" class="data row0 col4" >1500</td>
#         <td id="T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow0_col5" class="data row0 col5" >877.583</td>
#     </tr>    <tr>
#         <th id="T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3dlevel0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow1_col0" class="data row1 col0" >Germany</td>
#         <td id="T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow1_col1" class="data row1 col1" >98</td>
#         <td id="T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow1_col2" class="data row1 col2" >1</td>
#         <td id="T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow1_col3" class="data row1 col3" >775</td>
#         <td id="T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow1_col4" class="data row1 col4" >775</td>
#         <td id="T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow1_col5" class="data row1 col5" >775</td>
#     </tr>    <tr>
#         <th id="T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3dlevel0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow2_col0" class="data row2 col0" >France</td>
#         <td id="T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow2_col1" class="data row2 col1" >99</td>
#         <td id="T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow2_col2" class="data row2 col2" >10</td>
#         <td id="T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow2_col3" class="data row2 col3" >159</td>
#         <td id="T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow2_col4" class="data row2 col4" >2300</td>
#         <td id="T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3drow2_col5" class="data row2 col5" >632.4</td>
#     </tr>    <tr>
#         <th id="T_fb783f80_ac35_11e8_bf1d_b5cb727a4d3dlevel0_row3" class="row_heading level0 row3" >

# %% [markdown]
# ## Designation
# * The vineyard within the winery where the grapes that made the wine are from.
# * A [vineyard](#https://en.wikipedia.org/wiki/Vineyard) is a plantation of grape-bearing vines, grown mainly for winemaking, but also raisins, table grapes and non-alcoholic grape juice. The science, practice and study of vineyard production is known as viticulture.

# %%
print('Number of vineyard designation',wine['designation'].nunique())
cnt = wine.groupby(['designation'])['price'].mean().to_frame().sort_values(by='price',ascending=False)[:15]
f,ax = plt.subplots(1,2,figsize= (14,6))
ax1,ax2 = ax.flatten()
sns.barplot(cnt['price'], y = cnt.index, palette = 'Paired', ax = ax1)
ax1.set_xlabel('')
ax1.set_ylabel('Designation(Vineyard)')
ax1.set_title('Most expensive wine prepared in the vineyard')

cnt = wine.groupby(['designation'])['points'].mean().to_frame().sort_values(by = 'points', ascending = False)[:15]
sns.barplot(cnt['points'], y = cnt.index, palette = 'Set3', ax = ax2)
ax2.set_xlabel('')
ax2.set_ylabel('')
ax2.set_title('Most rated wine prepared in the vineyard')
plt.subplots_adjust(wspace=0.3)
# Out:
# Number of vineyard designation 47239

# %% [markdown]
# ## Winery
# * A [Winery](#https://en.wikipedia.org/wiki/Winery) is a building or property that produces wine, or a business involved in the production of wine, such as a wine company.

# %%
print('Number of winerys:',wine['winery'].nunique())
f,ax = plt.subplots(1,2,figsize=(16,6))
ax1,ax2 = ax.flatten()
cnt = wine.groupby(['winery'])['price'].max().to_frame().sort_values(by='price',ascending=False)[:15]
sns.barplot(cnt['price'],y = cnt.index,palette = 'ocean',ax = ax1)
ax1.set_title('The most expensive wine in prepared in the Winery')
cnt = wine.groupby(['winery'])['points'].max().to_frame().sort_values(by = 'points', ascending = False)[:15]
sns.barplot(cnt['points'], y = cnt.index, palette = 'hot')
plt.title('Most rated wine prepared in the Winery');
# Out:
# Number of winerys: 19186

# %% [markdown]
# ## Province
# * The province or state that the wine is from

# %%
print('Number of province:',wine['province'].nunique())
cnt = wine.groupby(['province'])['price'].mean().sort_values(ascending=False).to_frame()[:30]
plt.figure(figsize=(16,8))
squarify.plot(cnt['price'].fillna(0.001),label=cnt.index,color= sns.color_palette('Set3'))
plt.title('The average price of wine by province');
# Out:
# Number of province: 490

# %%
fig,ax = plt.subplots(1,2,figsize=(16,8))
ax1,ax2 = ax.flatten()

cnt = wine.groupby(['province'])['price'].max().sort_values(ascending=False).to_frame()[:15]
sns.barplot(x = cnt['price'], y = cnt.index, palette= 'RdBu',ax=ax1)
ax1.set_title('Most expensive wine availabe in the province')
ax1.set_ylabel('Variety')
ax1.set_xlabel('')
cnt = wine.groupby(['province'])['price'].min().sort_values(ascending=True).to_frame()[:15]
sns.barplot(x = cnt['price'], y = cnt.index, palette = 'summer',ax=ax2)
ax2.set_title('Least price wine availabel in the provice')
ax2.set_ylabel('')
ax2.set_xlabel('')
plt.subplots_adjust(wspace=0.3);

# %%
cnt = wine.groupby(['province','country','points'])['price'].agg(['count','min','max','mean']).sort_values(by='mean',ascending= False)[:10]
cnt.reset_index(inplace=True)
cnt.style.background_gradient(cmap='Blues',high=0.5)
# Out:
# <style  type="text/css" >
#     #T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow0_col2 {
#             background-color:  #539ecd;
#         }    #T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow0_col3 {
#             background-color:  #f7fbff;
#         }    #T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow0_col4 {
#             background-color:  #3787c0;
#         }    #T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow0_col5 {
#             background-color:  #3787c0;
#         }    #T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow0_col6 {
#             background-color:  #3787c0;
#         }    #T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow1_col2 {
#             background-color:  #3787c0;
#         }    #T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow1_col3 {
#             background-color:  #ccdff1;
#         }    #T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow1_col4 {
#             background-color:  #edf4fc;
#         }    #T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow1_col5 {
#             background-color:  #abd0e6;
#         }    #T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow1_col6 {
#             background-color:  #dae8f6;
#         }    #T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow2_col2 {
#             background-color:  #3787c0;
#         }    #T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow2_col3 {
#             background-color:  #ccdff1;
#         }    #T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow2_col4 {
#             background-color:  #f2f8fd;
#         }    #T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow2_col5 {
#             background-color:  #9fcae1;
#         }    #T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow2_col6 {
#             background-color:  #dce9f6;
#         }    #T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow3_col2 {
#             background-color:  #539ecd;
#         }    #T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow3_col3 {
#             background-color:  #f7fbff;
#         }    #T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow3_col4 {
#             background-color:  #caddf0;
#         }    #T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow3_col5 {
#             background-color:  #ddeaf7;
#         }    #T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow3_col6 {
#             background-color:  #ddeaf7;
#         }    #T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow4_col2 {
#             background-color:  #75b4d8;
#         }    #T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow4_col3 {
#             background-color:  #f7fbff;
#         }    #T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow4_col4 {
#             background-color:  #cee0f2;
#         }    #T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow4_col5 {
#             background-color:  #e3eef8;
#         }    #T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow4_col6 {
#             background-color:  #e3eef8;
#         }    #T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow5_col2 {
#             background-color:  #3787c0;
#         }    #T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow5_col3 {
#             background-color:  #f7fbff;
#         }    #T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow5_col4 {
#             background-color:  #d5e5f4;
#         }    #T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow5_col5 {
#             background-color:  #ecf4fb;
#         }    #T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow5_col6 {
#             background-color:  #ecf4fb;
#         }    #T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow6_col2 {
#             background-color:  #75b4d8;
#         }    #T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow6_col3 {
#             background-color:  #3787c0;
#         }    #T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow6_col4 {
#             background-color:  #f7fbff;
#         }    #T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow6_col5 {
#             background-color:  #65aad4;
#         }    #T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow6_col6 {
#             background-color:  #f1f7fd;
#         }    #T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow7_col2 {
#             background-color:  #539ecd;
#         }    #T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow7_col3 {
#             background-color:  #f7fbff;
#         }    #T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow7_col4 {
#             background-color:  #dae8f6;
#         }    #T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow7_col5 {
#             background-color:  #f2f8fd;
#         }    #T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow7_col6 {
#             background-color:  #f2f8fd;
#         }    #T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow8_col2 {
#             background-color:  #9cc9e1;
#         }    #T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow8_col3 {
#             background-color:  #c1d9ed;
#         }    #T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow8_col4 {
#             background-color:  #e1edf8;
#         }    #T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow8_col5 {
#             background-color:  #e3eef8;
#         }    #T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow8_col6 {
#             background-color:  #f3f8fe;
#         }    #T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow9_col2 {
#             background-color:  #f7fbff;
#         }    #T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow9_col3 {
#             background-color:  #f7fbff;
#         }    #T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow9_col4 {
#             background-color:  #deebf7;
#         }    #T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow9_col5 {
#             background-color:  #f7fbff;
#         }    #T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow9_col6 {
#             background-color:  #f7fbff;
#         }</style>
# <table id="T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3d" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >province</th>
#         <th class="col_heading level0 col1" >country</th>
#         <th class="col_heading level0 col2" >points</th>
#         <th class="col_heading level0 col3" >count</th>
#         <th class="col_heading level0 col4" >min</th>
#         <th class="col_heading level0 col5" >max</th>
#         <th class="col_heading level0 col6" >mean</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3dlevel0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow0_col0" class="data row0 col0" >Bordeaux</td>
#         <td id="T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow0_col1" class="data row0 col1" >France</td>
#         <td id="T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow0_col2" class="data row0 col2" >99</td>
#         <td id="T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow0_col3" class="data row0 col3" >1</td>
#         <td id="T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow0_col4" class="data row0 col4" >2300</td>
#         <td id="T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow0_col5" class="data row0 col5" >2300</td>
#         <td id="T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow0_col6" class="data row0 col6" >2300</td>
#     </tr>    <tr>
#         <th id="T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3dlevel0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow1_col0" class="data row1 col0" >Champagne</td>
#         <td id="T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow1_col1" class="data row1 col1" >France</td>
#         <td id="T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow1_col2" class="data row1 col2" >100</td>
#         <td id="T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow1_col3" class="data row1 col3" >6</td>
#         <td id="T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow1_col4" class="data row1 col4" >250</td>
#         <td id="T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow1_col5" class="data row1 col5" >1400</td>
#         <td id="T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow1_col6" class="data row1 col6" >887.667</td>
#     </tr>    <tr>
#         <th id="T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3dlevel0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow2_col0" class="data row2 col0" >Bordeaux</td>
#         <td id="T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow2_col1" class="data row2 col1" >France</td>
#         <td id="T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow2_col2" class="data row2 col2" >100</td>
#         <td id="T_fda7832e_ac35_11e8_bf1d_b5cb727a4d3drow2_col3" class="data row2 col3" >6</td>
#         <td id="T_fda7832e_ac35_11e8_bf1d_b5c

# %% [markdown]
# ## Region1
# * The wine growing area in a province or state

# %%
print('Number of province:',wine['region_1'].nunique())
cnt = wine.groupby(['region_1'])['price'].mean().sort_values(ascending=False).to_frame()[:30]
plt.figure(figsize=(16,8))
squarify.plot(cnt['price'].fillna(0.001),label=cnt.index,color= sns.color_palette('Oranges'))
plt.title('The average price of wine by province');
# Out:
# Number of province: 1332

# %%
cnt = wine.groupby(['country','province','points','region_1',])['price'].agg(
    ['count','min','max','mean']).sort_values(by = 'mean',ascending = False)[:20]
cnt.reset_index(inplace = True)
cnt.style.highlight_max()
# Out:
# <style  type="text/css" >
#     #T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow0_col5 {
#             background-color:  yellow;
#         }    #T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow0_col7 {
#             background-color:  yellow;
#         }    #T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow1_col6 {
#             background-color:  yellow;
#         }    #T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow2_col2 {
#             background-color:  yellow;
#         }    #T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow3_col2 {
#             background-color:  yellow;
#         }    #T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow6_col2 {
#             background-color:  yellow;
#         }    #T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow6_col4 {
#             background-color:  yellow;
#         }    #T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow9_col2 {
#             background-color:  yellow;
#         }    #T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow10_col6 {
#             background-color:  yellow;
#         }</style>
# <table id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3d" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >country</th>
#         <th class="col_heading level0 col1" >province</th>
#         <th class="col_heading level0 col2" >points</th>
#         <th class="col_heading level0 col3" >region_1</th>
#         <th class="col_heading level0 col4" >count</th>
#         <th class="col_heading level0 col5" >min</th>
#         <th class="col_heading level0 col6" >max</th>
#         <th class="col_heading level0 col7" >mean</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3dlevel0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow0_col0" class="data row0 col0" >France</td>
#         <td id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow0_col1" class="data row0 col1" >Bordeaux</td>
#         <td id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow0_col2" class="data row0 col2" >99</td>
#         <td id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow0_col3" class="data row0 col3" >Pauillac</td>
#         <td id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow0_col4" class="data row0 col4" >1</td>
#         <td id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow0_col5" class="data row0 col5" >2300</td>
#         <td id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow0_col6" class="data row0 col6" >2300</td>
#         <td id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow0_col7" class="data row0 col7" >2300</td>
#     </tr>    <tr>
#         <th id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3dlevel0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow1_col0" class="data row1 col0" >France</td>
#         <td id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow1_col1" class="data row1 col1" >Burgundy</td>
#         <td id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow1_col2" class="data row1 col2" >96</td>
#         <td id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow1_col3" class="data row1 col3" >La Romanée</td>
#         <td id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow1_col4" class="data row1 col4" >2</td>
#         <td id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow1_col5" class="data row1 col5" >2000</td>
#         <td id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow1_col6" class="data row1 col6" >2500</td>
#         <td id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow1_col7" class="data row1 col7" >2250</td>
#     </tr>    <tr>
#         <th id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3dlevel0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow2_col0" class="data row2 col0" >France</td>
#         <td id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow2_col1" class="data row2 col1" >Bordeaux</td>
#         <td id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow2_col2" class="data row2 col2" >100</td>
#         <td id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow2_col3" class="data row2 col3" >Saint-Émilion</td>
#         <td id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow2_col4" class="data row2 col4" >1</td>
#         <td id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow2_col5" class="data row2 col5" >1500</td>
#         <td id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow2_col6" class="data row2 col6" >1500</td>
#         <td id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow2_col7" class="data row2 col7" >1500</td>
#     </tr>    <tr>
#         <th id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3dlevel0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow3_col0" class="data row3 col0" >France</td>
#         <td id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow3_col1" class="data row3 col1" >Bordeaux</td>
#         <td id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow3_col2" class="data row3 col2" >100</td>
#         <td id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow3_col3" class="data row3 col3" >Pauillac</td>
#         <td id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow3_col4" class="data row3 col4" >1</td>
#         <td id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow3_col5" class="data row3 col5" >1500</td>
#         <td id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow3_col6" class="data row3 col6" >1500</td>
#         <td id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow3_col7" class="data row3 col7" >1500</td>
#     </tr>    <tr>
#         <th id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3dlevel0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow4_col0" class="data row4 col0" >France</td>
#         <td id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow4_col1" class="data row4 col1" >Bordeaux</td>
#         <td id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow4_col2" class="data row4 col2" >98</td>
#         <td id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow4_col3" class="data row4 col3" >Margaux</td>
#         <td id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow4_col4" class="data row4 col4" >4</td>
#         <td id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow4_col5" class="data row4 col5" >380</td>
#         <td id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow4_col6" class="data row4 col6" >1900</td>
#         <td id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow4_col7" class="data row4 col7" >1140</td>
#     </tr>    <tr>
#         <th id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3dlevel0_row5" class="row_heading level0 row5" >5</th>
#         <td id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow5_col0" class="data row5 col0" >France</td>
#         <td id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow5_col1" class="data row5 col1" >Burgundy</td>
#         <td id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow5_col2" class="data row5 col2" >94</td>
#         <td id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow5_col3" class="data row5 col3" >La Romanée</td>
#         <td id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow5_col4" class="data row5 col4" >1</td>
#         <td id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow5_col5" class="data row5 col5" >1125</td>
#         <td id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow5_col6" class="data row5 col6" >1125</td>
#         <td id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow5_col7" class="data row5 col7" >1125</td>
#     </tr>    <tr>
#         <th id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3dlevel0_row6" class="row_heading level0 row6" >6</th>
#         <td id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow6_col0" class="data row6 col0" >France</td>
#         <td id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow6_col1" class="data row6 col1" >Champagne</td>
#         <td id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow6_col2" class="data row6 col2" >100</td>
#         <td id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow6_col3" class="data row6 col3" >Champagne</td>
#         <td id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow6_col4" class="data row6 col4" >6</td>
#         <td id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow6_col5" class="data row6 col5" >250</td>
#         <td id="T_fe20b870_ac35_11e8_bf1d_b5cb727a4d3drow6_col6" class="data row6 col6" >1400</td>
#         <td

# %% [markdown]
# ## Region2
# * sometimes there are more specific regions specified within a wine growing area

# %%
print('Number of reqion2: ',wine['region_2'].nunique())
print('Null values in reqion2: ',wine['region_2'].isnull().sum())
cnt = wine.groupby(['country','province','region_1','region_2','points'])['price'].agg(
    ['count','min','max','mean']).sort_values(by = 'mean',ascending = False)[:20]
cnt.reset_index(inplace=True)
cnt.style.set_table_styles([{'selector': 'tr:hover','props': [('background-color', 'yellow')]}])
# Out:
# Number of reqion2:  18
# Null values in reqion2:  169437
# <style  type="text/css" >
#     #T_fe433954_ac35_11e8_bf1d_b5cb727a4d3d tr:hover {
#           background-color: yellow;
#     }</style>
# <table id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3d" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >country</th>
#         <th class="col_heading level0 col1" >province</th>
#         <th class="col_heading level0 col2" >region_1</th>
#         <th class="col_heading level0 col3" >region_2</th>
#         <th class="col_heading level0 col4" >points</th>
#         <th class="col_heading level0 col5" >count</th>
#         <th class="col_heading level0 col6" >min</th>
#         <th class="col_heading level0 col7" >max</th>
#         <th class="col_heading level0 col8" >mean</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3dlevel0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow0_col0" class="data row0 col0" >US</td>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow0_col1" class="data row0 col1" >California</td>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow0_col2" class="data row0 col2" >Sonoma County</td>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow0_col3" class="data row0 col3" >Sonoma</td>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow0_col4" class="data row0 col4" >97</td>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow0_col5" class="data row0 col5" >2</td>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow0_col6" class="data row0 col6" >450</td>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow0_col7" class="data row0 col7" >450</td>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow0_col8" class="data row0 col8" >450</td>
#     </tr>    <tr>
#         <th id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3dlevel0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow1_col0" class="data row1 col0" >US</td>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow1_col1" class="data row1 col1" >California</td>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow1_col2" class="data row1 col2" >Sonoma County</td>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow1_col3" class="data row1 col3" >Sonoma</td>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow1_col4" class="data row1 col4" >100</td>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow1_col5" class="data row1 col5" >1</td>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow1_col6" class="data row1 col6" >450</td>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow1_col7" class="data row1 col7" >450</td>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow1_col8" class="data row1 col8" >450</td>
#     </tr>    <tr>
#         <th id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3dlevel0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow2_col0" class="data row2 col0" >US</td>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow2_col1" class="data row2 col1" >California</td>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow2_col2" class="data row2 col2" >Sonoma County</td>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow2_col3" class="data row2 col3" >Sonoma</td>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow2_col4" class="data row2 col4" >98</td>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow2_col5" class="data row2 col5" >2</td>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow2_col6" class="data row2 col6" >300</td>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow2_col7" class="data row2 col7" >300</td>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow2_col8" class="data row2 col8" >300</td>
#     </tr>    <tr>
#         <th id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3dlevel0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow3_col0" class="data row3 col0" >US</td>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow3_col1" class="data row3 col1" >California</td>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow3_col2" class="data row3 col2" >Stags Leap District</td>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow3_col3" class="data row3 col3" >Napa</td>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow3_col4" class="data row3 col4" >98</td>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow3_col5" class="data row3 col5" >1</td>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow3_col6" class="data row3 col6" >265</td>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow3_col7" class="data row3 col7" >265</td>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow3_col8" class="data row3 col8" >265</td>
#     </tr>    <tr>
#         <th id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3dlevel0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow4_col0" class="data row4 col0" >US</td>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow4_col1" class="data row4 col1" >California</td>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow4_col2" class="data row4 col2" >Atlas Peak</td>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow4_col3" class="data row4 col3" >Napa</td>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow4_col4" class="data row4 col4" >99</td>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow4_col5" class="data row4 col5" >1</td>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow4_col6" class="data row4 col6" >250</td>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow4_col7" class="data row4 col7" >250</td>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow4_col8" class="data row4 col8" >250</td>
#     </tr>    <tr>
#         <th id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3dlevel0_row5" class="row_heading level0 row5" >5</th>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow5_col0" class="data row5 col0" >US</td>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow5_col1" class="data row5 col1" >California</td>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow5_col2" class="data row5 col2" >Rutherford</td>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow5_col3" class="data row5 col3" >Napa</td>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow5_col4" class="data row5 col4" >100</td>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow5_col5" class="data row5 col5" >2</td>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow5_col6" class="data row5 col6" >245</td>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow5_col7" class="data row5 col7" >245</td>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow5_col8" class="data row5 col8" >245</td>
#     </tr>    <tr>
#         <th id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3dlevel0_row6" class="row_heading level0 row6" >6</th>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow6_col0" class="data row6 col0" >US</td>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow6_col1" class="data row6 col1" >California</td>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow6_col2" class="data row6 col2" >Napa Valley</td>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow6_col3" class="data row6 col3" >Napa</td>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow6_col4" class="data row6 col4" >99</td>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow6_col5" class="data row6 col5" >7</td>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow6_col6" class="data row6 col6" >150</td>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow6_col7" class="data row6 col7" >300</td>
#         <td id="T_fe433954_ac35_11e8_bf1d_b5cb727a4d3drow6_col8" class="data row6 col8"

# %%
cnt = wine.groupby(['country','region_2']).count().reset_index()
cnt['country'].unique()
# Out:
# array(['US'], dtype=object)

# %% [markdown]
# * Region 2 details are available only for US

# %% [markdown]
# ## Taster Name
# * Name of the person who tasted and reviewed the wine

# %%
print(wine[['taster_name','taster_twitter_handle']].describe().T)
f,ax = plt.subplots(1,2, figsize = (16,8))
ax1,ax2 = ax.flatten()
sns.countplot(y = wine['taster_name'], palette = 'cividis', ax =ax1)
ax1.set_title('Taster Name')
ax1.set_xlabel('')
ax1.set_ylabel('')
sns.countplot(y = wine['taster_twitter_handle'], palette = 'ocean', ax =ax2)
ax2.set_title('Taser Twiter Handle')
ax2.set_xlabel('')
ax2.set_ylabel('');
# Out:
#                         count unique         top   freq
# taster_name            103727     19  Roger Voss  25514
# taster_twitter_handle   98758     15  @vossroger  25514

# %%
plt.figure(figsize = (16,6))
cnt = wine.groupby(['country','taster_name',]).count().reset_index()
sns.countplot(x = cnt['country'], palette='hot')
plt.xticks(rotation = 90);

# %% [markdown]
# ## Description:
# * A few sentences from a sommelier describing the wine's taste, smell, look, feel, etc.

# %%
plt.figure(figsize= (16,8))
plt.title('Word cloud of Description')
wc = WordCloud(max_words=1000,max_font_size=40,background_color='black', stopwords = STOPWORDS,colormap='Set1')
wc.generate(' '.join(wine['description']))
plt.imshow(wc,interpolation="bilinear")
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
plt.figure(figsize= (16,8))
plt.title('Word cloud of Description by France')
wc = WordCloud(max_words=1000,max_font_size=40,background_color='black', stopwords = STOPWORDS)
wc.generate(' '.join(wine[wine['country'] =='France']['description']))
plt.imshow(wc.recolor(colormap='Set2'),interpolation="bilinear")
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %% [markdown]
# ## Collabrative filtering
# A small recommender system is made using Nearest Neighbors algorithm.
#     * Similarity is the cosine of the angle between the 2 vectors of the item vectors of A and B
#     * Closer the vectors, smaller will be the angle and larger the cosine

# %%
from sklearn.neighbors import NearestNeighbors
from scipy.sparse import csr_matrix
from sklearn.decomposition import TruncatedSVD

# %%
wine1 = wine.copy()

# %%
# Lets choice rating of wine is points, title as user_id, and variety,
col = ['province','variety','points']
wine1 = wine[col]
wine1 = wine1.dropna(axis=0)
wine1 = wine1.drop_duplicates(['province','variety'])
wine1 = wine1[wine1['points'] >85]
wine_pivot = wine1.pivot(index= 'variety',columns='province',values='points').fillna(0)
wine_pivot_matrix = csr_matrix(wine_pivot)

# %%
knn = NearestNeighbors(n_neighbors=10,algorithm= 'brute', metric= 'cosine')
model_knn = knn.fit(wine_pivot_matrix)

# %% [markdown]
# ## Predict

# %%
query_index = np.random.choice(wine_pivot.shape[0])
distance, indice = model_knn.kneighbors(wine_pivot.iloc[query_index,:].values.reshape(1,-1),n_neighbors=6)
for i in range(0, len(distance.flatten())):
    if  i == 0:
        print('Recmmendation for {0}:\n'.format(wine_pivot.index[query_index]))
    else:
        print('{0}: {1} with distance: {2}'.format(i,wine_pivot.index[indice.flatten()[i]],distance.flatten()[i]))
# Out:
# Recmmendation for Cabernet Franc-Carmenère:
#
# 1: Torontel with distance: 0.30097365510403085
# 2: Carmenère-Syrah with distance: 0.48311841853962045
# 3: Carmenère-Cabernet Sauvignon with distance: 0.4943508285671865
# 4: Cabernet Sauvignon-Carmenère with distance: 0.49941376042741314
# 5: Syrah-Carignan with distance: 0.5003121838879427

# %% [markdown]
# ## Thank you for visiting
